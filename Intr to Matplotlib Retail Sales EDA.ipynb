# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #Dat Ingestion

# %%
Spark_df = spark.sql("select* from default.retail_sales_dataset")
df = Spark_df.toPandas()

df.head()

# %%
revenue_by_product = df.groupby("Product Category")["Total Amount"].sum()
print("Revenue by product" )
print(revenue_by_product)

# %%
df.info()

# %% [markdown]
# #First visualization

# %%
import matplotlib.pyplot as plt
import pandas as pd
revenue_by_product.plot(kind="bar")

plt.title("Revenue by product")
plt.xlabel("Product caretory")
plt.ylabel("Revenue")
plt.xticks(rotation=45)

# %% [markdown]
# #Time Based Analysis(Line chart)

# %%
df["date"] = pd.to_datetime(df["Date"])
df.info()

# %%
revenue_over_time = df.groupby("date")["Total Amount"].sum()

# %%
revenue_over_time.plot(kind="line")

plt.title("Revenue over time")
plt.xlabel("Date")
plt.ylabel("Revenue")
plt.show

# %% [markdown]
# #Student Exercise
# 1. Identify the worst perfoming product then
# 2. plot it
# 3. Explain why it might be underperfoming

# %%
worst_product = revenue_by_product.idxmin()
print("Worst perfoming product", worst_product)

# %%
revenue_by_product.plot(kind="bar")

plt.title("Worst perfoming product")
plt.xlabel("Product caretory")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()

# %%
#Location of the dataset
full_path = "/Workspace/Users/kamagaduzela10@gmail.com/retail_sales_dbx_repo/retail_sales_dataset.csv"

# %% [markdown]
# #Reading The Data

# %%
#Show the location of the data
df=pd.read_csv("/Workspace/Users/kamagaduzela10@gmail.com/retail_sales_dbx_repo/retail_sales_dataset.csv")

# %%
#Convert  date column date into date time
df['Date'] = pd.to_datetime(df['Date'])

# %%
#Creating new column monthname
